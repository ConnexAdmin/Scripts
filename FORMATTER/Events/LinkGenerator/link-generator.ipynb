# %%
import pandas as pd 
import numpy as np

# %%
df1 = pd.read_csv('events-input.csv')
#df2 = pd.read_csv('Testing_Valley-Applications_2023-12-17_00-06-35.csv')

# %%
df1.head()
# Out:
#                       Club                Name      Location  \
# 0  Valley Consulting Group  VCG Infosession #1  Dwinelle 241
# 1  Valley Consulting Group  VCG Infosession #2  Dwinelle 242
# 2  Valley Consulting Group  VCG Infosession #3  Dwinelle 243
# 3   Blockchain at Berkeley  BAB Infosession #1  Dwinelle 241
# 4   Blockchain at Berkeley  BAB Infosession #2  Dwinelle 242
#
#                  Date                                               Link
# 0  12/25/2023 7:00 PM  https://calendar.google.com/calendar/u/0/r/eve...
# 1  12/26/2023 7:00 PM                                                NaN
# 2  12/27/2023 7:00 PM                                                NaN
# 3  12/25/2023 7:00 PM                                                NaN
# 4  12/26/2023 7:00 PM                                                NaN

# %%
#df1 = pd.pivot_table(df1, values='answer-text', index='Name', columns='Question', aggfunc='first')
link = "https://calendar.google.com/calendar/u/0/r/eventedit?dates=20240121T030000Z/20240121T050000Z&details=Powered+by+Connex.+&location=Dwinelle+Hall+225&text=Valley+Infosession+%231"

# %%
for i in range(len(df1)):
    name = df1["Name"][i]
    name = name.replace(" ", "+")
    name = name.replace("#", "%23")
    print(name)
    location = df1["Location"][i]
    location = location.replace(" ", "+")
    print(location)
    date = pd.to_datetime(df1["Date"][i])
    print(date)
    dateStart = date + pd.Timedelta(days=0, hours=8)
    dateEnd = dateStart + pd.Timedelta(days = 0, hours = 2)
    startStr = dateStart.strftime('%Y%m%dT%H%M%S')
    endStr = dateEnd.strftime('%Y%m%dT%H%M%S')
    #print(date, startStr, endStr)
    df1["Link"][i] = "https://calendar.google.com/calendar/u/0/r/eventedit?dates={}Z/{}Z&details=Powered+by+Connex.+&location={}&text={}".format(startStr, endStr, location, name)
    print(df1["Link"][i])
# Out:
# VCG+Infosession+%231
# Dwinelle+241
# 2023-12-25 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231226T030000Z/20231226T050000Z&details=Powered+by+Connex.+&location=Dwinelle+241&text=VCG+Infosession+%231
# VCG+Infosession+%232
# Dwinelle+242
# 2023-12-26 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231227T030000Z/20231227T050000Z&details=Powered+by+Connex.+&location=Dwinelle+242&text=VCG+Infosession+%232
# VCG+Infosession+%233
# Dwinelle+243
# 2023-12-27 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231228T030000Z/20231228T050000Z&details=Powered+by+Connex.+&location=Dwinelle+243&text=VCG+Infosession+%233
# BAB+Infosession+%231
# Dwinelle+241
# 2023-12-25 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231226T030000Z/20231226T050000Z&details=Powered+by+Connex.+&location=Dwinelle+241&text=BAB+Infosession+%231
# BAB+Infosession+%232
# Dwinelle+242
# 2023-12-26 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231227T030000Z/20231227T050000Z&details=Powered+by+Connex.+&location=Dwinelle+242&text=BAB+Infosession+%232
# BAB+Infosession+%233
# Dwinelle+243
# 2023-12-27 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231228T030000Z/20231228T050000Z&details=Powered+by+Connex.+&location=Dwinelle+243&text=BAB+Infosession+%233
# Delta+Infosession+%231
# Dwinelle+241
# 2023-12-25 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231226T030000Z/20231226T050000Z&details=Powered+by+Connex.+&location=Dwinelle+241&text=Delta+Infosession+%231
# Delta+Infosession+%232
# Dwinelle+242
# 2023-12-26 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231227T030000Z/20231227T050000Z&details=Powered+by+Connex.+&location=Dwinelle+242&text=Delta+Infosession+%232
# Delta+Infosession+%233
# Dwinelle+243
# 2023-12-27 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231228T030000Z/20231228T050000Z&details=Powered+by+Connex.+&location=Dwinelle+243&text=Delta+Infosession+%233
# TBG+Infosession+%231
# Dwinelle+241
# 2023-12-25 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231226T030000Z/20231226T050000Z&details=Powered+by+Connex.+&location=Dwinelle+241&text=TBG+Infosession+%231
# TBG+Infosession+%232
# Dwinelle+242
# 2023-12-26 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231227T030000Z/20231227T050000Z&details=Powered+by+Connex.+&location=Dwinelle+242&text=TBG+Infosession+%232
# TBG+Infosession+%233
# Dwinelle+243
# 2023-12-27 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231228T030000Z/20231228T050000Z&details=Powered+by+Connex.+&location=Dwinelle+243&text=TBG+Infosession+%233
# MEBA+Infosession+%231
# Dwinelle+241
# 2023-12-25 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231226T030000Z/20231226T050000Z&details=Powered+by+Connex.+&location=Dwinelle+241&text=MEBA+Infosession+%231
# MEBA+Infosession+%232
# Dwinelle+242
# 2023-12-26 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231227T030000Z/20231227T050000Z&details=Powered+by+Connex.+&location=Dwinelle+242&text=MEBA+Infosession+%232
# MEBA+Infosession+%233
# Dwinelle+243
# 2023-12-27 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231228T030000Z/20231228T050000Z&details=Powered+by+Connex.+&location=Dwinelle+243&text=MEBA+Infosession+%233
# NIB+Infosession+%231
# Dwinelle+241
# 2023-12-25 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231226T030000Z/20231226T050000Z&details=Powered+by+Connex.+&location=Dwinelle+241&text=NIB+Infosession+%231
# NIB+Infosession+%232
# Dwinelle+242
# 2023-12-26 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231227T030000Z/20231227T050000Z&details=Powered+by+Connex.+&location=Dwinelle+242&text=NIB+Infosession+%232
# NIB+Infosession+%233
# Dwinelle+243
# 2023-12-27 19:00:00
# https://calendar.google.com/calendar/u/0/r/eventedit?dates=20231228T030000Z/20231228T050000Z&details=Powered+by+Connex.+&location=Dwinelle+243&text=NIB+Infosession+%233

# %%
df1.head()
# Out:
#                       Club                Name      Location  \
# 0  Valley Consulting Group  VCG Infosession #1  Dwinelle 242
# 1  Valley Consulting Group  VCG Infosession #2  Dwinelle 242
# 2  Valley Consulting Group  VCG Infosession #3  Dwinelle 242
# 3   Blockchain at Berkeley  BAB Infosession #1  Dwinelle 242
# 4   Blockchain at Berkeley  BAB Infosession #2  Dwinelle 242
#
#                   Date                                               Link
# 0  12/25/2023 12:22 AM  https://calendar.google.com/calendar/u/0/r/eve...
# 1  12/26/2023 12:22 AM  https://calendar.google.com/calendar/u/0/r/eve...
# 2  12/27/2023 12:22 AM  https://calendar.google.com/calendar/u/0/r/eve...
# 3  12/25/2023 12:22 AM  https://calendar.google.com/calendar/u/0/r/eve...
# 4  12/26/2023 12:22 AM  https://calendar.google.com/calendar/u/0/r/eve...

# %%
df3 = df2.merge(df1, on="Name").set_index("Name")

# %%
df3.to_csv("events-output.csv")
